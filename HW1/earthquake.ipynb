# %% [markdown]
# ### Task 2: Load the data

# %%
import pandas as pd

data = pd.read_csv("Earthquakes_USGS_1900-1950.csv")
data.head()
# Out:
#                           id  magnitude  \
# 0      cent19000105190000000        7.0
# 1      cent19000111090700000        7.0
# 2  official19000112171500000        NaN
# 3      cent19000120063300000        7.3
# 4  official19000128041500000        NaN
#
#                                        location       date  longitude  \
# 0                   Southern Sumatra, Indonesia   1/6/1900      102.0
# 1                                  Bismarck Sea  1/11/1900      148.0
# 2  Yakutat Bay, Alaska Earthquakes (Aftershock)  1/13/1900     -140.0
# 3                               Jalisco, Mexico  1/20/1900     -105.0
# 4  Yakutat Bay, Alaska Earthquakes (Aftershock)  1/28/1900     -140.0
#
#    latitude  depth
# 0      -3.0    NaN
# 1      -5.0    NaN
# 2      60.0    NaN
# 3      20.0    NaN
# 4      60.0    NaN

# %% [markdown]
# ### Task 3: Filter and analyze data

# %%
import numpy as np

total_earthquakes = len(data)
print("total earthquakes: " + str(total_earthquakes))

# Calculate the Average magnitude across all earthquakes
avg_magnitude = data["magnitude"].mean()
print("Average magnitude: " + str(avg_magnitude))

# Identify the top 5 strongest earthquakes by magnitude
top_5_strongest = data.sort_values(by="magnitude", ascending=False).head(5)
print(top_5_strongest)

# Find earthquakes deeper than 300 km
depth_300km = data[data["depth"] > 300]
print(depth_300km)
# Out:
# total earthquakes: 19925
# Average magnitude: 4.405054863306677
#                               id  magnitude  \
# 15279  official19460401122901_30        8.6
# 19419  official19500815140934_30        8.6
# 10435  official19380201190422_30        8.5
# 2057   official19221111043251_30        8.5
# 2090   official19230203160150_30        8.4
#
#                                                 location        date  \
# 15279  1946 Aleutian Islands (Unimak Island), Alaska ...    4/1/1946
# 19419                        1950 Assam-Tibet Earthquake   8/15/1950
# 10435                          1938 Banda Sea Earthquake    2/2/1938
# 2057                        94 km ENE of Vallenar, Chile  11/11/1922
# 2090                    121 km ESE of Mil’kovo, Russia    2/4/1923
#
#        longitude  latitude  depth
# 15279   -162.832    53.492   15.0
# 19419     96.445    28.363   15.0
# 10435    131.614    -5.045   25.0
# 2057     -69.852   -28.293   70.0
# 2090     160.472    54.486   15.0
#                           id  magnitude  \
# 85     cent19030104050700000        8.0
# 142          iscgemsup914301        7.4
# 148       iscgemsup600208131        NaN
# 231          iscgemsup914296        6.6
# 405          iscgemsup914257        6.6
# ...                      ...        ...
# 19589           iscgem895855        6.8
# 19749        iscgemsup896051        NaN
# 19823        iscgemsup896118        NaN
# 19865        iscgemsup896182        NaN
# 19913        iscgemsup896229        NaN
#
#                                       location        date  longitude  \
# 85                                       Tonga    1/4/1903   -175.000
# 142                   164 km NNE of Ama, Japan    6/7/1904    133.497
# 148    168 km NNE of Rengasdengklok, Indonesia   7/23/1904    107.684
# 231            5 km SE of Namyang, North Korea   8/25/1905    129.907
# 405                   90 km WNW of Sado, Japan   3/26/1907    137.461
# ...                                        ...         ...        ...
# 19589                              Fiji region   9/23/1950   -177.295
# 19749                231 km W of Hihifo, Tonga  11/10/1950   -175.941
# 19823             33 km W of Tarauacá, Brazil   12/2/1950    -71.073
# 19865            29 km NW of Tarauacá, Brazil  12/11/1950    -70.983
# 19913           40 km WNW of Tarauacá, Brazil  12/28/1950    -71.124
#
#        latitude  depth
# 85      -20.000  400.0
# 142      37.542  350.0
# 148      -4.690  600.0
# 231      42.921  470.0
# 405      38.354  360.0
# ...         ...    ...
# 19589   -17.634  400.4
# 19749   -16.223  340.0
# 19823    -8.144  643.3
# 19865    -8.003  644.5
# 19913    -8.086  635.0
#
# [315 rows x 7 columns]

# %% [markdown]
# ### Task 4: Generate a summary report

# %%
deep_earthquakes_count = len(depth_300km)

filename = "earthquake_report.txt"

with open(filename, "w", encoding="utf-8") as f:
    f.write(f"Total number of earthquakes = {total_earthquakes}\n")
    f.write(f"Average Magnitude = {avg_magnitude:.2f}\n")

    f.write("Top 5 Strongest Earthquakes\n")
    for i, (index, row) in enumerate(top_5_strongest.iterrows(), start=1):
        f.write(f"   {i}. {row['date']}, {row['location']}, {row['magnitude']}\n")

    f.write(f"Total numbers of earthquakes deeper than 300 km = {deep_earthquakes_count}\n")
